# %% [markdown]
# <a href="https://colab.research.google.com/github/zainabsajjad19/ML-capstone/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/zainabsajjad19/ML-capstone/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# I'm choosing the Refresh / Content Opportunity Scoring lane. I picked this over the others because it maps to a concrete, intuitive question — is this page growing, declining, or worth a second look — rather than a more abstract signal or clustering question. As someone new to ML, I wanted a lane where the label (growth vs. decline) is easy to define directly from the data, so I can focus on learning the workflow itself.## 1. My lane (or freestyle) and why

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# This work supports a content team's decision about where to spend limited review time each week. The action it drives: which pages get prioritized for a refresh, rewrite, or deeper audit. The cost of a wrong call: reviewing a page that's actually stable wastes review hours; missing a page that's actually declining means lost visibility and traffic that could have been caught early.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ### Uploading the CSV file
#
# To resolve the `FileNotFoundError`, you need to upload the `content_refresh_anonymized.csv` file to this Colab notebook's environment. You can do this using `google.colab.files.upload()` which will open a file selection dialog. Once uploaded, the file will be in the current working directory. Your code expects the file to be in `data/raw/`, so we'll create that directory and move the file there.

# %%
# Use this cell to upload your CSV file
from google.colab import files
import os

# This will open a file picker dialog
uploaded = files.upload()

# Get the filename from the uploaded dictionary
for filename in uploaded.keys():
    print(f'User uploaded file "{filename}" with length {len(uploaded[filename])} bytes')
    # Ensure the correct filename is used for subsequent operations
    uploaded_filename = filename
    break # Assuming only one file is uploaded at a time
# Out:
#      <input type="file" id="files-eb531920-ac8a-420f-a2b3-29cdde34fc37" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb531920-ac8a-420f-a2b3-29cdde34fc37">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Create the target directory if it doesn't exist
target_directory = 'data/raw'
os.makedirs(target_directory, exist_ok=True)

# Move the uploaded file to the target directory
# Replace 'content_refresh_anonymized.csv' with the actual filename if different
source_path = uploaded_filename # This variable is set in the previous cell
destination_path = os.path.join(target_directory, 'content_refresh_anonymized.csv')

os.rename(source_path, destination_path)
print(f'Moved "{source_path}" to "{destination_path}"')

print('\nNow you can run the cell below (cell K7RtgvsojNFo) to load the data.')

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print(df.describe())

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# My work will describe patterns as observed and directional e.g. "these pages showed declining engagement over the sampled window" and will support decisions rather than dictate them. It will never claim to predict or explain Google's ranking algorithm, nor claim proven causal impact from any single factor. Any recommendation is a decision-support signal, not a guarantee.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
