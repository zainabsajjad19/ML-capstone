# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/zainabsajjad19/ML-capstone/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# This is a scoring task (with an underlying binary classification at its core). I want to output a ranked list of pages — not just a yes/no label — so that a content team can review the highest-priority pages first. Under the hood, this is built from a classifier that predicts the probability a page falls into a "needs review" category, and I sort pages by that probability to produce the ranking.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# The target is a proxy label I define myself, not a directly observed outcome: I'll define "needs review" based on a decline in a traffic/visibility metric (e.g. clicks or impressions) over a defined time window compared to an earlier window. This is a rule-based proxy — it approximates "declining" but isn't a ground-truth outcome like a human editorial judgment would be.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# Precision@K (e.g. Precision@50) — of the top 50 pages my model flags as needing review, what fraction actually show meaningful decline by my defined proxy. I'm choosing this over overall accuracy because in a review-queue setting, what matters is whether the top of the list is trustworthy — the team will only ever look at the top few dozen pages, not the whole set.

# %% [markdown]
# ### Download Data
#
# First, let's ensure the data is available by downloading it from the GitHub repository and placing it in the expected directory structure.

# %%
import os

# Create the directory if it doesn't exist
os.makedirs('data/raw', exist_ok=True)

# %%
# Download the CSV file
# !wget -O data/raw/content_refresh_anonymized.csv https://raw.githubusercontent.com/zainabsajjad19/ML-capstone/main/data/raw/content_refresh_anonymized.csv

print("File downloaded successfully to data/raw/content_refresh_anonymized.csv")
# Out:
# --2026-07-24 19:43:28--  https://raw.githubusercontent.com/zainabsajjad19/ML-capstone/main/data/raw/content_refresh_anonymized.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6727670 (6.4M) [text/plain]
# Saving to: ‘data/raw/content_refresh_anonymized.csv’
#
# data/raw/content_re 100%[===================>]   6.42M  --.-KB/s    in 0.06s
#
# 2026-07-24 19:43:28 (107 MB/s) - ‘data/raw/content_refresh_anonymized.csv’ saved [6727670/6727670]
#
# File downloaded successfully to data/raw/content_refresh_anonymized.csv

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("One row =", "one page/URL, observed at a point in time")
print(df.shape)
df.head()
# Out:
# One row = one page/URL, observed at a point in time
# (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %% [markdown]
# A fixed rule like "flag any page with >X% drop in clicks" ignores that pages have very different baseline traffic, seasonality, and content types — a small page dropping 30% might be noise, while a large page dropping 10% might be a real signal. A model can weigh multiple signals together (traffic level, change magnitude, engagement, page type) and learn the combination that actually predicts meaningful decline, rather than relying on one brittle threshold that either over-flags or misses real cases.
#
# Now:## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule like "flag any page with >X% drop in clicks" ignores that pages have very different baseline traffic, seasonality, and content types — a small page dropping 30% might be noise, while a large page dropping 10% might be a real signal. A model can weigh multiple signals together (traffic level, change magnitude, engagement, page type) and learn the combination that actually predicts meaningful decline, rather than relying on one brittle threshold that either over-flags or misses real cases.
#
# Now:

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
